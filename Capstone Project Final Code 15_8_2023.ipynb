# %%
#importing Library
import pandas as pd

# %%
#fetching data from library csv
car_crash = pd.read_csv("C:\\Users\\praso\\Downloads\\Crash_Reporting_-_Drivers_Data1.csv")
car_crash
# Out:
# C:\Users\praso\AppData\Local\Temp\ipykernel_17260\1943965220.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   car_crash = pd.read_csv("C:\\Users\\praso\\Downloads\\Crash_Reporting_-_Drivers_Data1.csv")
#        Report Number Local Case Number                Agency Name  \
# 0         DD5620004G         190046109  Rockville Police Departme
# 1        MCP29620057         200023865   Montgomery County Police
# 2        MCP2651004P         210035267   Montgomery County Police
# 3        MCP3050004K         200016465   Montgomery County Police
# 4        MCP2641001J         200016526   Montgomery County Police
# ...              ...               ...                        ...
# 159733    EJ786600C2         230022848  Gaithersburg Police Depar
# 159734   MCP2534004P         230021665   Montgomery County Police
# 159735   MCP3086008W         230023486   Montgomery County Police
# ...

# %%
#Checking Columns Name
car_crash.columns
# Out:
# Index(['Report Number', 'Local Case Number', 'Agency Name', 'ACRS Report Type',
#        'Crash_Date_Time', 'Route Type', 'Road Name', 'Cross-Street Type',
#        'Cross-Street Name', 'Off-Road Description', 'Municipality',
#        'Related Non-Motorist', 'Collision Type', 'Weather',
#        'Surface Condition', 'Light', 'Traffic Control',
#        'Driver Substance Abuse', 'Non-Motorist Substance Abuse', 'Person ID',
#        'Driver At Fault', 'Injury Severity', 'Circumstance',
#        'Driver Distracted By', 'Drivers License State', 'Vehicle ID',
#        'Vehicle Damage Extent', 'Vehicle First Impact Location',
#        'Vehicle Second Impact Location', 'Vehicle Body Type',
#        'Vehicle Movement', 'Vehicle Continuing Dir', 'Vehicle Going Dir',
#        'Speed_Limit', 'Driverless Vehicle', 'Parked Vehicle', 'Vehicle_Year',
#        'Vehicle Make', 'Vehicle Model', 'Equipment Problems', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
#How Many Rows & Columns We Have
car_crash.shape
# Out:
# (159738, 43)

# %%
#Checking Null Values
car_crash.isnull().sum()
# Out:
# Report Number                          1
# Local Case Number                      1
# Agency Name                            1
# ACRS Report Type                       1
# Crash_Date_Time                        1
# Route Type                             0
# Road Name                          14812
# Cross-Street Type                  15721
# Cross-Street Name                  14821
# Off-Road Description              144928
# Municipality                      142002
# Related Non-Motorist              154702
# Collision Type                       539
# Weather                            12517
# Surface Condition                  18744
# Light                               1327
# Traffic Control                    23969
# Driver Substance Abuse             29071
# Non-Motorist Substance Abuse      155751
# Person ID                              1
# Driver At Fault                        1
# Injury Severity                        1
# Circumstance                      130291
# ...

# %%
#dropping columns
car_crash = car_crash.drop(["Off-Road Description","Municipality","Related Non-Motorist","Non-Motorist Substance Abuse","Circumstance"
                           ,"Vehicle ID", "Equipment Problems","Latitude","Longitude","Location","Drivers License State",
                           "Vehicle Damage Extent", "Vehicle First Impact Location", "Vehicle Second Impact Location",
                           "Vehicle Body Type","Vehicle Movement", "Vehicle Continuing Dir", "Vehicle Going Dir", "Vehicle_Year",
                           "Vehicle Model" ], axis = 1)

# %%
car_crash = car_crash.drop(["Cross-Street Type","Cross-Street Name","Driver Distracted By","Vehicle Make",
                           "ACRS Report Type", "Traffic Control", "Report Number", "Local Case Number", "Agency Name"
                           , "Crash_Date_Time", "Person ID"] , axis = 1)

# %%
#checking final columns
car_crash.columns
# Out:
# Index(['Route Type', 'Road Name', 'Collision Type', 'Weather',
#        'Surface Condition', 'Light', 'Driver Substance Abuse',
#        'Driver At Fault', 'Injury Severity', 'Speed_Limit',
#        'Driverless Vehicle', 'Parked Vehicle'],
#       dtype='object')

# %%
#Checking Null Values
car_crash.isnull().sum()
# Out:
# Route Type                    0
# Road Name                 14812
# Collision Type              539
# Weather                   12517
# Surface Condition         18744
# Light                      1327
# Driver Substance Abuse    29071
# Driver At Fault               1
# Injury Severity               1
# Speed_Limit                   1
# Driverless Vehicle            1
# Parked Vehicle                1
# dtype: int64

# %%
#dropping na rows
car_crash.dropna(inplace=True)
car_crash.head(5)
# Out:
#      Route Type     Road Name     Collision Type Weather Surface Condition  \
# 1        County  DAIRYMAID DR              OTHER  CLOUDY               DRY
# 3        County    RUSSETT RD              OTHER   CLEAR               DRY
# 4        County   ARCHDALE RD              OTHER  CLOUDY               DRY
# 6  Municipality  WOOTTON PKWY  SAME DIR REAR END   CLEAR               DRY
# 7        County    CASHELL RD     SINGLE VEHICLE  CLOUDY               DRY
#
#       Light Driver Substance Abuse Driver At Fault     Injury Severity  \
# 1   UNKNOWN                UNKNOWN             Yes  NO APPARENT INJURY
# 3  DAYLIGHT        ALCOHOL PRESENT             Yes  NO APPARENT INJURY
# 4  DAYLIGHT          NONE DETECTED             Yes     POSSIBLE INJURY
# 6      DAWN          NONE DETECTED              No  NO APPARENT INJURY
# 7  DAYLIGHT          NONE DETECTED              No  NO APPARENT INJURY
#
#    Speed_Limit Driverless Vehicle Parked Vehicle
# ...

# %%
#checking columns droped or not
car_crash.shape
# Out:
# (108284, 12)

# %%
#checking datatypes
car_crash.dtypes
# Out:
# Route Type                 object
# Road Name                  object
# Collision Type             object
# Weather                    object
# Surface Condition          object
# Light                      object
# Driver Substance Abuse     object
# Driver At Fault            object
# Injury Severity            object
# Speed_Limit               float64
# Driverless Vehicle         object
# Parked Vehicle             object
# dtype: object

# %%
# Compute counts for each attribute
route_type_counts = car_crash['Route Type'].value_counts()
road_name_counts = car_crash['Road Name'].value_counts()
collision_type_counts = car_crash['Collision Type'].value_counts()
surface_condition_counts = car_crash['Surface Condition'].value_counts()
light_counts = car_crash['Light'].value_counts()
driver_substance_abuse_counts = car_crash['Driver Substance Abuse'].value_counts()
driver_at_fault_counts = car_crash['Driver At Fault'].value_counts()
injury_severity_counts = car_crash['Injury Severity'].value_counts()
speed_limit_counts = car_crash['Speed_Limit'].value_counts()
driverless_vehicle_counts = car_crash['Driverless Vehicle'].value_counts()
parked_vehicle_counts = car_crash['Parked Vehicle'].value_counts()

# %%
import matplotlib.pyplot as plt

# Visualization 1: Route Type (Bar Plot)
plt.bar(route_type_counts.index, route_type_counts.values, color='purple')
plt.xlabel('Route Type')
plt.ylabel('Number of Crashes')
plt.title('Crashes by Route Type')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualization 2: Road Name (Bar Plot)
plt.bar(road_name_counts.index, road_name_counts.values, color='blue')
plt.xlabel('Road Name')
plt.ylabel('Number of Crashes')
plt.title('Crashes by Road Name')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualization 3: Collision Type (Bar Plot)
plt.bar(collision_type_counts.index, collision_type_counts.values, color='green')
plt.xlabel('Collision Type')
plt.ylabel('Number of Crashes')
plt.title('Crashes by Collision Type')
plt.xticks(rotation=90)
plt.show()

# %%
#Visulization 4:Weather 
# Calculate the count of car crashes for each unique weather condition
weather_counts = car_crash['Weather'].value_counts()

# Visualization 4: Weather (Bar Plot)
plt.figure(figsize=(10, 6))
plt.bar(weather_counts.index, weather_counts.values, color='blue')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Crashes')
plt.title('Crashes by Weather Condition')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Visualization 5: Surface Condition (Bar Plot)
plt.bar(surface_condition_counts.index, surface_condition_counts.values, color='Green')
plt.xlabel('Surface Condition')
plt.ylabel('Number of Crashes')
plt.title('Crashes by Road Surface Condition')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualization 6: Light (Bar Plot)
plt.bar(light_counts.index, light_counts.values, color='purple')
plt.xlabel('Light')
plt.ylabel('Number of Crashes')
plt.title('Crashes by Lighting Condition')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualization 7: Driver Substance Abuse (Bar Plot)
plt.bar(driver_substance_abuse_counts.index, driver_substance_abuse_counts.values, color='blue')
plt.xlabel('Driver Substance Abuse')
plt.ylabel('Number of Crashes')
plt.title('Crashes by Driver Substance Abuse')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualization 8: Driver At Fault (Pie Chart)
plt.pie(driver_at_fault_counts.values, labels=driver_at_fault_counts.index, autopct='%1.1f%%')
plt.title('Crashes by Driver At Fault')
plt.show()

# %%
# Visualization 9: Injury Severity (Pie Chart)

import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(car_crash['Injury Severity'])  
plt.xlabel('Injury Severity')
plt.ylabel('Count')
plt.title('Distribution of Injury Severity')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\praso\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Visulazition 10
# Histogram of Speed Limit variable

plt.hist(car_crash['Speed_Limit'], bins=10, color='orange', edgecolor='black') 
plt.xlabel('Speed_Limit')
plt.ylabel('Frequency')
plt.title('Distribution of Speed Limit')
plt.show()

# %%
# Visualization 11: Driverless Vehicle (Bar Plot)
plt.bar(driverless_vehicle_counts.index, driverless_vehicle_counts.values, color='purple')
plt.xlabel('Driverless Vehicle')
plt.ylabel('Number of Crashes')
plt.title('Crashes involving Driverless Vehicles')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualization 12: Parked Vehicle (Pie Chart)
plt.pie(parked_vehicle_counts.values, labels=parked_vehicle_counts.index, autopct='%1.1f%%')
plt.title('Crashes involving Parked Vehicles')
plt.show()

# %%
#changing Dtypes
car_crash["Route Type"] = car_crash["Route Type"].astype("category")

# %%
car_crash["Weather"] = car_crash["Weather"].astype("category")

# %%
car_crash["Light"] = car_crash["Light"].astype("category")

# %%
car_crash["Surface Condition"] = car_crash["Surface Condition"].astype("category")

# %%
car_crash["Injury Severity"] = car_crash["Injury Severity"].astype("category")

# %%
car_crash["Collision Type"] = car_crash["Collision Type"].astype("category")

# %%
car_crash["Road Name"] = car_crash["Road Name"].astype("category")

# %%
car_crash["Driver Substance Abuse"] = car_crash["Driver Substance Abuse"].astype("category")

# %%
car_crash["Driverless Vehicle"] = car_crash["Driverless Vehicle"].astype("category")

# %%
car_crash["Parked Vehicle"] = car_crash["Parked Vehicle"].astype("category")

# %%
car_crash["Driver At Fault"] = car_crash["Driver At Fault"].astype("category")

# %%
#cat codes command

car_crash["Route Type"] = car_crash["Route Type"].cat.codes

# %%
car_crash["Weather"] = car_crash["Weather"].cat.codes

# %%
car_crash["Light"] = car_crash["Light"].cat.codes

# %%
car_crash["Surface Condition"] = car_crash["Surface Condition"].cat.codes

# %%
car_crash["Collision Type"] = car_crash["Collision Type"].cat.codes

# %%
car_crash["Road Name"] = car_crash["Road Name"].cat.codes

# %%
car_crash["Driver Substance Abuse"] = car_crash["Driver Substance Abuse"].cat.codes

# %%
car_crash["Driverless Vehicle"] = car_crash["Driverless Vehicle"].cat.codes

# %%
car_crash["Parked Vehicle"] = car_crash["Parked Vehicle"].cat.codes

# %%
car_crash["Driver At Fault"] = car_crash["Driver At Fault"].cat.codes

# %%
#checking dtypes
car_crash.dtypes
# Out:
# Route Type                    int8
# Road Name                    int16
# Collision Type                int8
# Weather                       int8
# Surface Condition             int8
# Light                         int8
# Driver Substance Abuse        int8
# Driver At Fault               int8
# Injury Severity           category
# Speed_Limit                float64
# Driverless Vehicle            int8
# Parked Vehicle                int8
# dtype: object

# %%
car_crash.head(54119)
# Out:
#        Route Type  Road Name  Collision Type  Weather  Surface Condition  \
# 1               0        696               7        3                  0
# 3               0       2535               7        2                  0
# 4               0         89               7        3                  0
# 6               4       3182               9        2                  0
# 7               0        454              15        3                  0
# ...           ...        ...             ...      ...                ...
# 80043           0       2056              16        2                  0
# 80044           4        385               4        3                  0
# 80045           3       1402              14        3                  0
# 80046           3       2936              14        2                  0
# 80047           4       1712              15        2                  0
#
#        Light  Driver Substance Abuse  Driver At Fault     Injury Severity  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Histogram of Speed Limit variable

plt.hist(car_crash['Speed_Limit'], bins=10, color='orange', edgecolor='black') 
plt.xlabel('Speed_Limit')
plt.ylabel('Frequency')
plt.title('Distribution of Speed Limit')
plt.show()

# %%
import seaborn as sns

# %%
# Bar plot of Agency Name variable
plt.figure(figsize=(8, 6))
sns.countplot(car_crash['Injury Severity'])  
plt.xlabel('Injury Severity')
plt.ylabel('Count')
plt.title('Distribution of Injury Severity')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\praso\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Pie Chart

categorical_variable = "Injury Severity"

# Calculate the value counts for the selected categorical variable
category_counts = car_crash[categorical_variable].value_counts()

# Create a pie chart
plt.figure(figsize=(10, 9))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', shadow=True)
plt.title(f"Pie Chart for {categorical_variable}")
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular
plt.show()

# %%
car_crash.head(15)
# Out:
#     Route Type  Road Name  Collision Type  Weather  Surface Condition  Light  \
# 1            0        696               7        3                  0      7
# 3            0       2535               7        2                  0      4
# 4            0         89               7        3                  0      4
# 6            4       3182               9        2                  0      3
# 7            0        454              15        3                  0      4
# 9            3       1402               9        2                  0      1
# 13           3       2070              14        2                  0      4
# 14           3       1402               9        2                  0      1
# 18           3        578              16        2                  0      4
# 20           8        612               9        2                  0      3
# 23           0        441               1        2                  0      0
# ...

# %%
import numpy as np

# %%
car_crash.columns
# Out:
# Index(['Route Type', 'Road Name', 'Collision Type', 'Weather',
#        'Surface Condition', 'Light', 'Driver Substance Abuse',
#        'Driver At Fault', 'Injury Severity', 'Speed_Limit',
#        'Driverless Vehicle', 'Parked Vehicle'],
#       dtype='object')

# %%
independent = car_crash[['Route Type', 'Road Name', 'Collision Type', 'Weather',
       'Surface Condition', 'Light', 'Driver Substance Abuse',
       'Driver At Fault']]

# %%
independent
# Out:
#         Route Type  Road Name  Collision Type  Weather  Surface Condition  \
# 1                0        696               7        3                  0
# 3                0       2535               7        2                  0
# 4                0         89               7        3                  0
# 6                4       3182               9        2                  0
# 7                0        454              15        3                  0
# ...            ...        ...             ...      ...                ...
# 159729           3        601               9        2                  0
# 159730           0       3150              15        2                  0
# 159732           3       1057              16        2                  0
# 159734           0        750               7        2                  0
# 159736           3       1963              16        3                 10
#
#         Light  Driver Substance Abuse  Driver At Fault
# ...

# %%
dependent = car_crash['Injury Severity']
dependent
# Out:
# 1         NO APPARENT INJURY
# 3         NO APPARENT INJURY
# 4            POSSIBLE INJURY
# 6         NO APPARENT INJURY
# 7         NO APPARENT INJURY
#                  ...
# 159729       POSSIBLE INJURY
# 159730    NO APPARENT INJURY
# 159732    NO APPARENT INJURY
# 159734    NO APPARENT INJURY
# 159736       POSSIBLE INJURY
# Name: Injury Severity, Length: 108284, dtype: category
# Categories (5, object): ['FATAL INJURY', 'NO APPARENT INJURY', 'POSSIBLE INJURY', 'SUSPECTED MINOR INJURY', 'SUSPECTED SERIOUS INJURY']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(independent,dependent, test_size=0.2, random_state=3 )

# %%
x_train
# Out:
#         Route Type  Road Name  Collision Type  Weather  Surface Condition  \
# 66230            3       2936              16        2                  0
# 65905            3       2952               9        2                  0
# 113946           0       1882              15        3                 10
# 120833           4       1651               1        2                  0
# 138553           3       1832               3        2                  1
# ...            ...        ...             ...      ...                ...
# 71170            2        429              15        6                 10
# 87235            3       1917               9        2                  0
# 113701           3        623              16        2                  0
# 99207            3       2952              16        2                  0
# 105578           0       1886              15        2                  0
#
#         Light  Driver Substance Abuse  Driver At Fault
# ...

# %%
x_test
# Out:
#         Route Type  Road Name  Collision Type  Weather  Surface Condition  \
# 4774             3       2952              14        2                  0
# 109945           5       1885               9        2                  0
# 65740            3       2056               9        2                  0
# 65554            0        643               9        2                  0
# 95178            0        741               9        2                  0
# ...            ...        ...             ...      ...                ...
# 112636           3       1057              14        9                 10
# 14210            2        429              14        2                  0
# 43279            3        623               9        2                  0
# 32324            3        601              15        2                  0
# 10874            3       1402              14        2                  0
#
#         Light  Driver Substance Abuse  Driver At Fault
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
stndrd = StandardScaler()
x_train = pd.DataFrame(stndrd.fit_transform(x_train),columns = x_train.columns)

# %%
x_train
# Out:
#        Route Type  Road Name  Collision Type   Weather  Surface Condition  \
# 0        0.401961   1.411712        1.294411 -0.491119          -0.512179
# 1        0.401961   1.429439       -0.372167 -0.491119          -0.512179
# 2       -1.113278   0.243888        1.056328  0.129466           1.992535
# 3        0.907041  -0.012058       -2.276828 -0.491119          -0.512179
# 4        0.401961   0.188488       -1.800662 -0.491119          -0.261707
# ...           ...        ...             ...       ...                ...
# 86622   -0.103118  -1.366025        1.056328  1.991220           1.992535
# 86623    0.401961   0.282668       -0.372167 -0.491119          -0.512179
# 86624    0.401961  -1.151074        1.294411 -0.491119          -0.512179
# 86625    0.401961   1.429439        1.294411 -0.491119          -0.512179
# 86626   -1.113278   0.248320        1.056328 -0.491119          -0.512179
#
#           Light  Driver Substance Abuse  Driver At Fault
# ...

# %%
x_test = pd.DataFrame(stndrd.fit_transform(x_test),columns = x_test.columns)

# %%
x_test
# Out:
#        Route Type  Road Name  Collision Type   Weather  Surface Condition  \
# 0        0.392475   1.427884        0.817364 -0.493309          -0.510853
# 1        1.400758   0.247379       -0.378661 -0.493309          -0.510853
# 2        0.392475   0.436569       -0.378661 -0.493309          -0.510853
# 3       -1.119950  -1.126742       -0.378661 -0.493309          -0.510853
# 4       -1.119950  -1.018317       -0.378661 -0.493309          -0.510853
# ...           ...        ...             ...       ...                ...
# 21652    0.392475  -0.668702        0.817364  3.843820           1.996069
# 21653   -0.111667  -1.363507        0.817364 -0.493309          -0.510853
# 21654    0.392475  -1.148869       -0.378661 -0.493309          -0.510853
# 21655    0.392475  -1.173210        1.056569 -0.493309          -0.510853
# 21656    0.392475  -0.287001        0.817364 -0.493309          -0.510853
#
#           Light  Driver Substance Abuse  Driver At Fault
# ...

# %%
#Question Predicting the severity of accidents based on weather conditions and other factors?

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 7)
knn
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(x_train, y_train)
pred_k = knn.predict(x_test)
pred_k
# Out:
# C:\Users\praso\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# array(['NO APPARENT INJURY', 'POSSIBLE INJURY', 'NO APPARENT INJURY', ...,
#        'NO APPARENT INJURY', 'NO APPARENT INJURY', 'NO APPARENT INJURY'],
#       dtype=object)

# %%
y_test
# Out:
# 4774      NO APPARENT INJURY
# 109945    NO APPARENT INJURY
# 65740     NO APPARENT INJURY
# 65554     NO APPARENT INJURY
# 95178     NO APPARENT INJURY
#                  ...
# 112636    NO APPARENT INJURY
# 14210     NO APPARENT INJURY
# 43279     NO APPARENT INJURY
# 32324     NO APPARENT INJURY
# 10874     NO APPARENT INJURY
# Name: Injury Severity, Length: 21657, dtype: category
# Categories (5, object): ['FATAL INJURY', 'NO APPARENT INJURY', 'POSSIBLE INJURY', 'SUSPECTED MINOR INJURY', 'SUSPECTED SERIOUS INJURY']

# %%
from sklearn.metrics import accuracy_score

# %%
Knn_acc = accuracy_score(y_test,pred_k)*100

# %%
print("Knn classifier accuracy =", round(Knn_acc,2),"%")
# Out:
# Knn classifier accuracy = 79.63 %

# %%
pred_k = knn.predict(x_test)
# Out:
# C:\Users\praso\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Create the confusion matrix
ck = confusion_matrix(y_test, pred_k)
print("Confusion Matrix:")
print(ck)
# Out:
# Confusion Matrix:
# [[    1    21     0     0     0]
#  [    0 17174   185    74     1]
#  [    0  2303    50    23     0]
#  [    0  1587    22    20     0]
#  [    0   191     2     3     0]]

# %%
# Create a heatmap of the confusion matrix using seaborn
sns.heatmap(ck, annot=True, fmt='d', cmap='Blues')

# Add labels, title, and axis ticks
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

# Show the plot
plt.show()

# %%
#Importing Libraries

from sklearn.model_selection import cross_validate

# %%
x = car_crash[['Route Type', 'Road Name', 'Collision Type', 'Weather',
       'Surface Condition', 'Light', 'Driver Substance Abuse',
       'Driver At Fault']]

# %%
y = car_crash['Injury Severity']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state = 100)

# %%
#importing decision tree 
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
#performing with entropy 

clf_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 100, max_depth = 5, min_samples_leaf = 10)
clf_entropy.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=10,
#                        random_state=100)

# %%
y_pred_en = clf_entropy.predict(x_test)
print(y_pred_en)
# Out:
# ['NO APPARENT INJURY' 'NO APPARENT INJURY' 'NO APPARENT INJURY' ...
#  'NO APPARENT INJURY' 'NO APPARENT INJURY' 'NO APPARENT INJURY']

# %%
print("Accuracy is ", accuracy_score(y_test,y_pred_en)*100)
# Out:
# Accuracy is  80.34230129902112

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred_en)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[    0    45     0     0     0]
#  [    0 26100     0     0     0]
#  [    0  3538     0     0     0]
#  [    0  2498     0     0     0]
#  [    0   305     0     0     0]]

# %%
import pandas as pd

# Create a Pandas DataFrame from the data
car_crash = pd.DataFrame(car_crash)

# Calculate the correlation matrix using Pearson method
pearson_corr_matrix = car_crash.corr(method='pearson')

# Calculate the correlation matrix using Spearman method
spearman_corr_matrix = car_crash.corr(method='spearman')

print("Pearson Correlation Matrix:")
print(pearson_corr_matrix)

print("\nSpearman Correlation Matrix:")
print(spearman_corr_matrix)
# Out:
# Pearson Correlation Matrix:
#                         Route Type  Road Name  Collision Type   Weather  \
# Route Type                1.000000  -0.088023       -0.001648 -0.035054
# Road Name                -0.088023   1.000000       -0.013577 -0.001121
# Collision Type           -0.001648  -0.013577        1.000000  0.011868
# Weather                  -0.035054  -0.001121        0.011868  1.000000
# Surface Condition        -0.038874  -0.004920        0.013622  0.769441
# Light                    -0.012401   0.013346       -0.024154 -0.050386
# Driver Substance Abuse    0.022425   0.007036       -0.013322  0.024441
# Driver At Fault          -0.049243  -0.013185        0.070378  0.019679
# Speed_Limit               0.196853  -0.045621       -0.026227 -0.002815
# Driverless Vehicle       -0.004073  -0.004184        0.010058  0.012989
# Parked Vehicle           -0.026526  -0.007871       -0.014086  0.000282
#
# ...

# %%
# Create a heatmap of the confusion matrix using seaborn
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

# Add labels, title, and axis ticks
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

# Show the plot
plt.show()
